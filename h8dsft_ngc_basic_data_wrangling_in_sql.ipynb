# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

auth.authenticate_user()

project_id = "booming-key-403108"
client = bigquery.Client(project=project_id)

# put your query here
query = """SELECT*FROM`bigquery-public-data.austin_bikeshare.bikeshare_trips`"""

# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#           trip_id     subscriber_type bike_id bike_type  \
# 0        29774671             Local31   19645  electric
# 1        29712533             Local31   21739  electric
# 2        29494413            Local365   19224  electric
# 3        29551831     3-Day Weekender   21650  electric
# 4        29560653  Student Membership   19646  electric
# ...           ...                 ...     ...       ...
# 2047230  26620000            Explorer   21767  electric
# 2047231  26686177  Student Membership   19251  electric
# 2047232  26792047             Local31   21447  electric
# 2047233  26793893             Local31   21447  electric
# 2047234  26494898  Student Membership   23271  electric
#
#                        start_time  start_station_id  \
# 0       2023-05-31 13:10:04+00:00              3794
# 1       2023-05-24 23:13:59+00:00              2823
# 2       2023-05-01 15:27:15+00:00              4047
# 3       2023-05-06 22:41:20+00:00              3794
# ...

# %%
# Soal nomer 1
# pada austin_bikeshare terdapat 2 table yaitu bikeshare_stations dan bikeshare_trips

# put your query here
query = """SELECT*FROM`bigquery-public-data.austin_bikeshare.__TABLES__`"""

# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#              project_id        dataset_id            table_id  creation_time  \
# 0  bigquery-public-data  austin_bikeshare  bikeshare_stations  1495683814344
# 1  bigquery-public-data  austin_bikeshare     bikeshare_trips  1689612093433
#
#    last_modified_time  row_count  size_bytes  type
# 0       1698192466565        102       13163     1
# 1       1698192203376    2047235   238296603     1

# %%
# Soal nomer 2
# Table bikeshare_stations memiliki kolom bertipe data string sebanyak 7 kolom

# put your query here
query = """  SELECT
    * EXCEPT(is_generated, generation_expression, is_stored, is_updatable)
  FROM
    `bigquery-public-data`.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS
  WHERE
    table_name = 'bikeshare_stations';"""

# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#            table_catalog      table_schema          table_name  \
# 0   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 1   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 2   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 3   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 4   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 5   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 6   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 7   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 8   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 9   bigquery-public-data  austin_bikeshare  bikeshare_stations
# 10  bigquery-public-data  austin_bikeshare  bikeshare_stations
# 11  bigquery-public-data  austin_bikeshare  bikeshare_stations
# 12  bigquery-public-data  austin_bikeshare  bikeshare_stations
# 13  bigquery-public-data  austin_bikeshare  bikeshare_stations
#
# ...

# %%
#nomer 3

# put your query here
query = """SELECT*FROM`bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE duration_minutes > 1000 AND bike_id is NOT NULL;
"""

# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#        trip_id       subscriber_type bike_id bike_type  \
# 0     29731917  24 Hour Walk Up Pass   21457  electric
# 1     29731920  24 Hour Walk Up Pass   21803  electric
# 2     29554935       Pay-as-you-ride   21454  electric
# 3     30391277               Local31   23277  electric
# 4     30163408  24 Hour Walk Up Pass    2887   classic
# ...        ...                   ...     ...       ...
# 3553  28004099    Student Membership   19677  electric
# 3554  27141342    Student Membership   19314  electric
# 3555  27393789    Student Membership   19085  electric
# 3556  27815785    Student Membership   22431  electric
# 3557  28335547    Student Membership   21496  electric
#
#                     start_time  start_station_id  \
# 0    2023-05-27 10:47:04+00:00              3791
# 1    2023-05-27 10:47:20+00:00              3791
# 2    2023-05-07 11:44:09+00:00              4048
# 3    2023-07-30 11:23:37+00:00              3794
# 4    2023-07-08 23:42:32+00:00              3794
# ...

# %%
#nomer 4
# put your query here
query = """SELECT*FROM`bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE subscriber_type = "Walk Up" AND end_station_name = "Stolen";
"""

# Set up the query
query_job = client.query(query).to_dataframe()

query_job
# Out:
#     trip_id subscriber_type bike_id bike_type                start_time  \
# 0  13564817         Walk Up     393   classic 2017-01-28 04:57:28+00:00
# 1  11712091         Walk Up     327   classic 2016-09-02 06:37:15+00:00
# 2  11714202         Walk Up     122   classic 2016-09-02 09:00:56+00:00
# 3  13857913         Walk Up     135   classic 2017-02-26 14:32:45+00:00
# 4  13555129         Walk Up     578   classic 2017-01-27 01:35:26+00:00
# 5  17151360         Walk Up    1899   classic 2018-04-21 15:29:10+00:00
# 6  16898448         Walk Up    1857   classic 2018-03-18 22:51:20+00:00
# 7  16863172         Walk Up    1795   classic 2018-03-14 21:23:26+00:00
#
#    start_station_id                                 start_station_name  \
# 0              2561  State Capitol Visitors Garage @ San Jacinto & ...
# 1              2565                               Trinity & 6th Street
# 2              2565                               Trinity & 6th Street
# ...
